# %%
import pandas as pd

# %%
file_path = 'construct.csv'
df_construct = pd.read_csv(file_path)
df_construct = df_construct.drop_duplicates()
df_construct.to_csv(file_path)

# %%
file_path = 'subject.csv'
df_subject = pd.read_csv(file_path)
df_subject = df_subject.drop_duplicates()
df_subject.to_csv(file_path)
