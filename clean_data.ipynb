# %%
import pandas as pd

# %%
file_path = 'construct.csv'
df_construct = pd.read_csv(file_path)
df_construct
# Out:
#      construct_id                                     construct_name
# 0             856  Use the order of operations to carry out calcu...
# 1            1612  Simplify an algebraic fraction by factorising ...
# 2            2774            Calculate the range from a list of data
# 3            2377  Recall and use the intersecting diagonals prop...
# 4            3387  Substitute positive integer values into formul...
# ..            ...                                                ...
# 752           988  Sketch curves in the form (x + a)(x + b) indic...
# 753          1549  Given a positive x value, find the correspondi...
# 754          1874  Calculate distance where speed and time are in...
# 755          2904  Identify when it is appropriate to use a line ...
# 756          2634      Distinguish between congruency and similarity
#
# [757 rows x 2 columns]

# %%
file_path = 'subject.csv'
df_subject = pd.read_csv(file_path)
df_subject.head()
# Out:
#    subject_id                                       subject_name
# 0          33                                             BIDMAS
# 1        1077                    Simplifying Algebraic Fractions
# 2         339  Range and Interquartile Range from a List of Data
# 3          88                       Properties of Quadrilaterals
# 4          67                          Substitution into Formula

# %%
file_path = 'question.csv'
df_question = pd.read_csv(file_path)
df_question
# Out:
#       question_id  construct_id  subject_id correct_answer  \
# 0               0           856          33              A
# 1               1          1612        1077              D
# 2               2          2774         339              B
# 3               3          2377          88              C
# 4               4          3387          67              A
# ...           ...           ...         ...            ...
# 1864         1864          2774         339              C
# 1865         1865          2695          90              B
# 1866         1866           854          33              B
# 1867         1867          2634         274              B
# 1868         1868          2680          93              B
#
#                                           question_text  \
# 0     \[\n3 \times 2+4-5\n\]\nWhere do the brackets ...
# 1     Simplify the following, if possible: \( \frac{...
# 2     Tom and Katie are discussing the \( 5 \) plant...
# 3     The angles highlighted on this rectangle with ...
# 4     The equation \( f=3 r^{2}+3 \) is used to find...
# ...                                                 ...
# 1864  What is the range of the following numbers?\n\...
# 1865  Shape \( Q \) is an enlargement of shape \( P ...
# 1866  What does the following equal?\n\[\n8-7+10 \ti...
# 1867  Tom and Katie are discussing congruence and si...
# 1868  Jo and Paul are arguing about how to fully des...
#
#               answer_a_text           answer_b_text          answer_c_text  \
# 0     \( 3 \times(2+4)-5 \)  \( 3 \times 2+(4-5) \)  \( 3 \times(2+4-5) \)
# 1                 \( m+1 \)               \( m+2 \)              \( m-1 \)
# 2                 Only\nTom             Only\nKatie     Both Tom and Katie
# 3                     acute                  obtuse       \( 90^{\circ} \)
# 4                  \( 30 \)                \( 27 \)               \( 51 \)
# ...                     ...                     ...                    ...
# 1864                \( 5 \)                \( 11 \)               \( 23 \)
# 1865        \( 3 \div 11 \)         \( 11 \div 3 \)      \( 3 \times 11 \)
# 1866               \( 36 \)                \( 31 \)              \( -29 \)
# 1867              Only\nTom              Only Katie     Both Tom and Katie
# 1868               Only\nJo               Only Paul       Both Jo and Paul
#
#                answer_d_text  misconception_a_id  misconception_b_id  \
# 0     Does not need brackets                 NaN                 NaN
# 1          Does not simplify              2142.0               143.0
# 2         Neither is correct              1287.0                 NaN
# 3     Not enough information              1180.0              1180.0
# 4                   \( 24 \)                 NaN                 NaN
# ...                      ...                 ...                 ...
# 1864                \( 16 \)              2456.0               691.0
# 1865              \( 11-3 \)              1500.0                 NaN
# 1866                \( 33 \)                 NaN                 NaN
# 1867      Neither is correct              2312.0                 NaN
# 1868      Neither is correct               801.0                 NaN
#
#       misconception_c_id  misconception_d_id
# 0                    NaN              1672.0
# 1                 2142.0                 NaN
# 2                 1287.0              1073.0
# 3                    NaN              1180.0
# 4                    NaN              1818.0
# ...                  ...                 ...
# 1864                 NaN              1349.0
# 1865              2442.0              1258.0
# 1866              2306.0              1507.0
# 1867              2312.0              2312.0
# 1868               801.0                95.0
#
# [1869 rows x 13 columns]

# %%
file_path = 'subject.csv'
df_subject = pd.read_csv(file_path)
df_subject
# Out:
#      subject_id                                       subject_name
# 0            33                                             BIDMAS
# 1          1077                    Simplifying Algebraic Fractions
# 2           339  Range and Interquartile Range from a List of Data
# 3            88                       Properties of Quadrilaterals
# 4            67                          Substitution into Formula
# ..          ...                                                ...
# 158          89                                      2D Pythagoras
# 159         217                               Basic Calculator Use
# 160         273              Length, Area and Volume Scale Factors
# 161        1170                        Straight Line Graphs-Others
# 162         332                               Currency Conversions
#
# [163 rows x 2 columns]
